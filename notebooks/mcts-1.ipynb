# %% [markdown]
# # Monte Carlo Search
#
# Inspired by the [Monte Carlo Tree Refine paper](https://arxiv.org/pdf/2406.07394).
#
# The goal is to improve the quality of responses generated by LLms, done by:
# 1. Start with a seed answer, "I don't know".
# 2. Ask the LLM to suggest improvements to the seed answer.
# 3. Use the suggestions from #2 to provide three improved responses. (temp=1 --> variance)
# 4. Randomly select one response and use the LLM to rate that response (out of 100).
# 5. Calculate the UCT for the nodes (Upper Confidence bound applied to Trees) (based on the rating).
# 6. Traverse the tree following the nodes with the highest UCT.
# 7. Create new nodes (via suggestion, improvement, rating)... etc.

# %% [markdown]
# $$ \text{UCT} = \frac{\text{total reward of the node}}{\text{number of visits to the node}} + \text{exploration constant} \cdot \sqrt{\frac{\text{ln(number of visits to the parent node)}}{\text{number of visits to the node}}} $$

# %% [markdown]
# ### LLM Endpoint
# You can use:
# - OpenAI
# - Run an OpenAI compatible endpoint using a service like Runpod:
#     - One click Llama 3 8b vLLM template [here](https:runpod.io/console/deploy?template=4qmr18da9x&ref=jmfkcdio).
#     - Other models [here](https://github.com/TrelisResearch/one-click-llms)
# - Groq
# - Any other openai compatible endpoint.

# %%
from getpass import getpass
from dotenv import load_dotenv
import os

load_dotenv()
groq_key = os.getenv("GROQ_KEY", "Empty")

# Input the values
model = getpass("Enter the model name: ")
api_endpoint = getpass("Enter the API endpoint (default: https://api.openai.com): ")
# api_key = getpass("Enter the API key (press enter to leave empty, e.g for Runpod): ")

# Notes for Runpod:
#- Model should be the slug on HuggingFace, e.g. "NousResearch/Meta-Llama-3-8B-Instruct"
#- endpoint should be "https://{POD-ID}-8000.proxy.runpod.net", e.g. "https://yhpj2mzxpl8pcn-8000.proxy.runpod.net"

## Notes for Groq
#- Model should be "llama3-8b-8192"
#- endpoint should be "https://api.groq.com/openai"

# Set the variables with defaults
api_endpoint = api_endpoint if api_endpoint else "https://api.openai.com"
api_key = groq_key

# Construct the OpenAI API base
openai_api_base = f"{api_endpoint}/v1"

# Print the values
print(f"Model: {model}")
print(f"API Endpoint: {api_endpoint}")
print(f"OpenAI API Base: {openai_api_base}")
if api_key == "Empty":
    print("No API key needed.")
else:
    print(f"API Key Set")
    # print(f"API Key: {api_key}") # comment in to print for testing
# Out:
# Model: llama3-8b-8192
# API Endpoint: https://api.groq.com/openai
# OpenAI API Base: https://api.groq.com/openai/v1
# API Key Set

# %%
# # Manually update the model groq
# model = "llama3-70b-8192"
# model = "llama3-8b-8192"

# %%
from openai import OpenAI
import re # support for regex

# Initialize the OpenAI API client
client = OpenAI(
    api_key=api_key,
    base_url=openai_api_base
)

def chat_completion_request_openai(prompt): # function that will call the OpenAI API
    messages = [
        {"role": "user", "content": prompt}
    ]
    # Create chat completions using the OpenAI client
    chat_response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=1.0,
        max_tokens=1500,
    )

    # Extract the completion text from the response
    if chat_response.choices:
        completion_text = chat_response.choices[0].message.content
    else:
        completion_text = "No response from the model."
    return completion_text

# Test the endpoint
if __name__ == "__main__":
    # Test the function
    prompt = "Return an array of string, where each string is a season"
    chat_response = chat_completion_request_openai(prompt)
    print(f"Prompt: {prompt}\n")
    print(f"Response: {chat_response}")
# Out:
# Prompt: Return an array of string, where each string is a season
#
# Response: Here is an array of strings, where each string is a season:
# ```
# ["Spring", "Summer", "Autumn", "Winter"]
# ```
# Let me know if you need anything else!

# %%
# Set up seed answers
seed_answers = [
    "I don't know the answer",
    "I'm not sure",
    "I can't say",
]

# %% [markdown]
# ### Answer Improvement and Rating Pipeline
# These are three steps to:
# 1. Critique --> get suggestions for improvement
# 2. Improve --> generating actual improved answers
# 3. Rate --> rate the improved answer (used when calculating UCT)
# a given answer to a question

# %%
# Get Critique
def get_critique(question, draft_answer):
    prompt = (
        f"Question: {question}\n"
        f"Draft Answer: {draft_answer}\n"
        "Please critique the draft answer. "
        "Do a careful assessment of whether the answer is correct or not, and why. "
        "Consider multiple ways of verifying the correctness of the answer. "
        "Point out every flaw and hold the draft answer to a high standard. "
        "Do provide specific recommendations to improve the answer. "
        "Do think step by step."
        "Do not provide a revised answer." # Constrain the answer to be only a critique
    )
    # Create the request to the LLM
    return chat_completion_request_openai(prompt)

# test the function
if __name__ == "__main__":
    question = "What is the capital of France?"
    draft_answer = "The capital of France is Lyon." # Wrong it is Paris
    critique = get_critique(question, draft_answer)
    print(critique)
# Out:
# Let's conduct a thorough critique of the draft answer:
#
# The draft answer states that the capital of France is Lyon.
#
#  Assessment:
#
# * Initial impression: The answer seems incorrect. Lyon is a major city in eastern France, but it is not the capital.
# * Verification method 1: Checking a reference book or online resource. According to reputable sources such as the CIA World Factbook, the official government website of France, and numerous travel websites, the capital of France is actually Paris, not Lyon.
# * Verification method 2: Searching for official government websites. The Government of France's official website (gouvernement.fr) confirms that Paris is the capital of France, and Lyon is a major city in a different region.
# * Verification method 3: Consulting a map. A glance at a map of France would also indicate that Paris is the capital, not Lyon.
#
# Flaws:
#
# * Inaccuracy: The answer is incorrect. Lyon is not the capital of France.
# * Lack of evidence: The draft answer does not provide any credible evidence or sources to support its claim.
# * Lack of research: It appears that the draft answer was not thoroughly researched or verified.
#
# Recommendations:
#
# * Conduct thorough research: Verify information through reputable sources, official government websites, and peer-reviewed materials.
# * Double-check answers: Take the time to cross-check answers with multiple sources to ensure accuracy.
# * Provide evidence: Support answers with credible sources or references to demonstrate the research and verification process.
# * Consider multiple perspectives: Consider different viewpoints, opinions, and sources to avoid errors.
#
# By following these recommendations, the draft answer can be significantly improved to ensure accuracy and credibility.

# %%
import re

def improve_answer(question, draft_answer, critique):
    prompt = (
        f"Question: {question}\n"
        f"Draft Answer: {draft_answer}\n"
        f"Critique: {critique}\n\n"
        "Please improve the draft answer based on the critique. Following this format:\n"
        "Reasoning Process: <step-by-step reasoning process>\n"
        "Verfication: <verification of the facts>\n"
        "Final Answer: <the improved and verified answer>\n"
    )
    # Create the request to the LLM
    return chat_completion_request_openai(prompt)

# Test the function
if __name__ == "__main__":
    question = "What is the capital of France?"
    draft_answer = "The capital of France is Lyon." # Wrong it is Paris
    critique = "That's just wrong"
    improved_answer = improve_answer(question, draft_answer, critique)
    print(f"--Improved Answer--\n{improved_answer}\n")
# Out:
# --Improved Answer--
# Here's the improved draft answer:
#
# Reasoning Process:
#
# 1. Recognize the mistake: The initial answer states that Lyon is the capital of France, which is incorrect.
# 2. Know the correct information: France's capital is a well-known fact, and it is not Lyon.
# 3. Update the answer: With the correct information, we can provide a revised answer that accurately states the capital of France.
#
# Verification:
#
# * Verified through multiple reliable sources, including the French government's official website, Wikipedia, and other reputable online resources.
# * Confirmed that the capital of France is indeed Paris, not Lyon.
#
# Final Answer:
#
# The capital of France is Paris.

# %%
import re

def rate_answer(question, answer):
    prompt = (
        f"Question: {question}\n"
        f"Answer: {answer}\n"
        "As an expert on this topic, please provide a detailed critique of the answer, pointing out every flaw. "
        "Provide only a critique, not a suggested answer. "
        "Then, rate the answer on a scale of 0 to 100. "
        "The response should be in the following format:\n"
        "Critique: <detailed critique>\n"
        "Rating: <rating>\n"
    )
    # Create the request to the LLM
    rating_response = chat_completion_request_openai(prompt)
    print(f"{rating_response}\n")

    # Extract the rating
    try:
        match = re.search(r"Rating:\s*(\d+)", rating_response) # Extract rating to be used in the UCT calculation
        if match:
            rating = int(match.group(1))
            if rating > 95: # Paper limits the rating to a maximum of 95 (maybe 96+ causes poor MCTS performance)
                rating = 95
            rating = float(rating)/100
        else:
            raise ValueError("Rating not found in the response.")
    except Exception as e:
        print(f"Error extracting rating: {e}")
        print(f"Rating response was: {rating_response}")
        rating = 0

    return rating

# Test the function
if __name__ == "__main__":
    question = "What is the capital of France?"
    answer = "The capital of France is Paris."
    rating = rate_answer(question, answer)
    print(f"Critique: {critique}")
    print(f"\nReward/Rating: {rating}")
    # Lower rating because of this: 
    # As an expert on this topic, please provide a detailed critique of the answer, pointing out every flaw.
    # --> Since "The capital of France is Paris." doesn't provide an explanation, it is not seen as a "good" answer.

    # Moral of the story is:
    # Rating criteria is really important and should be relaxed or tightened depending on the task. 
    # In this case, the rating criteria is too strict and penalizes good answers that are not "explanatory" enough.
# Out:
# Critique:
#
# The answer provided is simplistic and lacks any significant analysis or examination of the question. It is a straightforward, one-word response that does not demonstrate any critical thinking or comprehension of the question. The answer does not provide any context, history, or description of the city of Paris, which is the capital of France. Additionally, the answer does not consider other potential answers or arguments that could be made.
#
# The answer is too brief and fails to engage with the complexity of the question, instead opting for a superficial, surface-level response. As a result, it lacks depth, nuance, and insight.
#
# Rating: 20
#
# (Note: A rating of 0 would indicate a completely incorrect answer, while a rating of 100 would indicate a perfect answer that fully addresses the question. The rating of 20 reflects the simplicity and lack of depth of the answer.)
#
# Critique: That's just wrong
#
# Reward/Rating: 0.2

# %%
# Direct/Simple LLM Query
def get_answer_directly_from_llm(question): # Baseline comparison (just querying the LLM normally without any help from MTCS)
    prompt = (
        f"Question: {question}\n" # Prompting is similar to the MCTS one --> better baseline for comparison
        "Please provide the answer with detailed reasoning. Follow this format:\n"
        "Reasoning Process: <step-by-step reasoning process>\n"
        "Verification: <verification of the facts>\n"
        "Final Answer: <the verified answer>\n"
    )
    llm_response = chat_completion_request_openai(prompt)

    # Extract the final answer
    try:
        match = re.search(r'Final Answer:\s*(.*)', llm_response, re.DOTALL)
        final_answer = match.group(1).strip() if match else None
    except Exception as e:
        final_answer = None

    return llm_response, final_answer

# %%
import math
import random
import numpy as np

max_children = 3 # Generate 3 answers per terminal node reached
# To increase the variance at each node --> increase max_children

class Node:
    def __init__(self, question, answer, parent=None):
        self.question = question
        self.answer = answer
        self.parent = parent
        self.children = []
        self.visits = 0 # Number of times we consider a child of this node (since we will backpropogate the reward to all the parents of that child)
        self.value = 0.0 # Accumulated reward (everytime we evaluate a child node --> we will backpropogate/update the value of all of its parents by adding it to the parent's current value (accumulated reward))
    
    def is_fully_expanded(self): # Have we created the maximum number of children for this node? --> if yes, we will not expand it anymore
        return len(self.children) >= max_children
    
    def best_child(self, exploration_weights=1.41): # Used to determine what path we want to follow in the tree (we always want to follow the best child path)
        choices_weights = []
        for child in self.children:
            if child.visits == 0:
                weight = float('inf') # Prioritize unexplored nodes
            else:
                weight = (child.value / child.visits) + exploration_weights * math.sqrt(2 * math.log(self.visits) / child.visits) # UCT calculation
                # Exploration term --> (child.value / child.visits) --> basically the average reward of the child
                # Exploitation term --> exploration_weights * math.sqrt(2 * math.log(self.visits) / child.visits) --> will be very high for unexplored nodes which will encourage exploration down that path
            choices_weights.append(weight)
        return self.children[np.argmax(choices_weights)] # Return the child with the highest UCT value
    
    def most_visited_child(self): # This is used to pull the best trajectory from the MCTS tree once its generation is done (best trajectory == most likely to be the correct answer)
        return max(self.children, key=lambda child: child.visits) # Return the child with the most visits
    
    def add_child(self, child_node): # Utility function used to expand the tree
        self.children.append(child_node)
    
class MCTS:
    def __init__(self, question, seed_answers, iterations=2):
        self.question = question
        self.seed_answers = seed_answers
        self.iterations = iterations # Number of times that we will go through the full process of: generating children, evaluating one of them, and propagating back the reward
        self.root = Node(question, random.choice(seed_answers)) # Randomly select a seed answer to start with

    def search(self):
        for i in range(self.iterations):
            print(f"\nIteration {i+1}/{self.iterations}")
            node = self.select(self.root) # Select a node to expand
            print(f"Selected node: {node.answer}")
            if not node.is_fully_expanded():
                node = self.expand(node) # Expand the ndode
                print(f"\nExpanded node: {node.answer}")
            reward = self.simulate(node) # Simulate one of the expanded children
            print(f"\nSimulated reward: {reward}")
            self.backpropagate(node, reward) # Backpropogate the reward of the simulated child 
        print(f"Visits to most visited child: {self.root.most_visited_child().visits}")
        return self.root.most_visited_child().answer
    
    def select(self, node): # While nodes are fully expanded, move down the path generated by the nodes with the highest UCT value (best child)
        while node.is_fully_expanded() and node.children:
            node = node.best_child()
        return node
    
    def expand(self, node):
        for j in range(max_children - len(node.children)): # Repeat for 3 children nodes
            child_node = Node(self.question, node.answer, parent=node) # Initialize the child node with the same question and answer as the parent node
            node.add_child(child_node)

            critique = get_critique(self.question, child_node.answer) # Get the critique of the child node's answer (answer is the same as the parent node)
            print(f"\n--Critique {j}--\n{critique}")

            improved_answer = improve_answer(self.question, child_node.answer, critique) # Get the improved answer of the child node with the critique
            print(f"\n--Improved Answer {j}--\n{improved_answer}")

            child_node.answer = improved_answer # Updated the child node's answer with the improved answer
        return random.choice(node.children) # Randomly select one of the children to simulate (this is the child who's reward will backpropogate) (this is the standard simulation protocol for MCTS)
    
    def simulate(self, node):
        rating = rate_answer(self.question, node.answer) # Get the rating of the child node's answer through the LLM (not true simulation)
        return rating # This will be backpropogated to all parent nodes of the current node
    
    def backpropagate(self, node, reward):
        while node is not None:
            node.visits += 1
            node.value += reward
            print(f"Backpropagating reward {reward} to node: {node.answer}")
            node = node.parent # Move up the tree to the parent node


# Set the question and seed answers
question = "What is the capital of France?"

# Initialize and run MCTS
mcts = MCTS(question, seed_answers, iterations=2) # 2 iterations for testing
best_answer = mcts.search() # Main function that runs the MCTS algorithm
print(f"\nBest Answer: {best_answer}")
# Out:
# Iteration 1/2
# Selected node: I can't say
#
# --Critique 0--
# Here's my critique of the draft answer:
#
# **Initial Assessment:** The draft answer states that it cannot say the capital of France. This is an unusual response, as it's not a typical mistake or uncertainty.
#
# **Verify the Correctness of the Answer:** To verify the correctness of the answer, I would check the answer using multiple sources:
#
# 1. Check online encyclopedias (e.g., Wikipedia, Encyclopedia Britannica) for the capital of France.
# 2. Consult a reliable geography or world atlas.
# 3. Check official government websites of France (e.g., French Ministry of Foreign Affairs, French Embassy).
#
# **Flawed Assumptions:** The draft answer assumes a level of uncertainty that is unwarranted. While it's possible to admit uncertainty about a minor fact, the capital of France is a well-established and widely known fact that can be easily verified.
#
# **Recommendations to Improve the Answer:**
#
# 1. **Provide a clear response:** Instead of saying "I can't say," simply state the correct answer (e.g., "The capital of France is Paris.").
# 2. **Verify the answer:** Before providing an answer, take a moment to quickly check it using one or more of the methods outlined above to ensure its accuracy.
# 3. **Avoid ambiguity:** Instead of saying "I can't say," rephrase the answer to focus on the clarity and confidence of the response, such as "Without a doubt, the capital of France is Paris."
# 4. **Show, don't tell:** Rather than stating an uncertainty, demonstrate your understanding of the question by providing a clear and correct answer.
#
# By following these recommendations, the draft answer can be significantly improved to provide a clear, accurate, and confident response.
#
# --Improved Answer 0--
# Here is the improved answer:
#
# Reasoning Process:
# To determine the capital of France, I will start by checking reputable sources such as online encyclopedias, atlas, and official government websites.
#
# Verification:
#  According to multiple sources, including Wikipedia, Encyclopedia Britannica, and the French Ministry of Foreign Affairs, the capital of France is indeed Paris.
#
# Final Answer:
# The capital of France is Paris.
#
# --Critique 1--
# Let's critically assess the draft answer.
#
# **Claim:** The capital of France is unknown (I can't say).
#
# **Problems:**
#
# 1. **Unclear intention**: The answer is ambiguous and doesn't explicitly state that the question is unknown. It's unclear whether the intention is to acknowledge a lack of knowledge or to deliberately remain silent.
# 2. **Lack of evidence**: There is no attempt to verify the answer or provide supporting information. This opens up the possibility that the answer may be incorrect or incomplete.
# 3. **Inconsistency**: If the intention is to acknowledge a lack of knowledge, it's inconsistent with the fact that you can easily verify the capital of France through various sources.
#
# **Verification methods:**
#
# 1. **Check a reliable encyclopedia**: Wikipedia, Britannica, or other trusted sources can provide accurate information about the capital of France.
# 2. **Consult official government websites**: The government of France or other reputable institutions can also confirm the capital.
# 3. **Use a map or atlas**: Physical or digital maps can quickly show the location of the capital.
#
# **Recommendations to improve the answer:**
#
# 1. **Clearly state the intention**: If the answer is unknown, say so explicitly. Acknowledge the uncertainty and provide context (e.g., "I don't have information about the capital of France" or "I'm not sure about the capital of France").
# 2. **Provide alternatives**: Suggest possible ways to verify the answer or offer alternatives (e.g., "You can check a comprehensive guidebook or consult a reliable online source" or "You can also use a map or atlas to locate the capital").
# 3. **Use evidence-based reasoning**: Incorporate credible sources to support the answer. If necessary, indicate that further research is needed to confirm the answer.
#
# By addressing these issues, the draft answer can be improved to provide a clearer, more informative, and evidence-based response.
#
# --Improved Answer 1--
# **Reasoning Process:**
#
# 1. I acknowledge that the question is asking about the capital of France.
# 2. I recognize that I may not have immediate access to specific information or knowledge about the capital.
# 3. I consider the possibility that I might be able to verify the answer through reliable sources or consult with other resources.
#
# **Verification:**
#
# I checked multiple reliable sources, including Wikipedia, Britannica, and official government websites, to confirm the capital of France. Additionally, I verified the information using a digital map and atlas.
#
# **Final Answer:**
#
# The capital of France is Paris.
#
# **Rationale:**
#
# Based on my verification process, I confidently state that the capital of France is indeed Paris. This answer is supported by credible sources and can be easily verified through various means. If unclear or uncertain about the answer, I would explicitly acknowledge my limitations and suggest alternatives for further research or verification.
#
# --Critique 2--
# Let's critique the draft answer!
#
# **Flaw 1: Vagueness**
# The draft answer starts with "I can't say", which is a vague and incomplete response. It doesn't provide any information about the capital of France. Vagueness is not an acceptable response in a Q&A system.
#
# **Flaw 2: Lack of effort**
# The draft answer seems to imply that the user didn't bother to find the answer or verify it. A good answer should demonstrate some level of effort and research.
#
# **Verification**
# To verify the correctness of the answer, we can use several methods:
#
# 1. Check online resources: Look up trusted sources like Wikipedia, government websites, or encyclopedias to find the capital of France.
# 2. Ask a colleague: Consult with someone who might know the answer or can provide a reliable reference.
# 3. Check existing answers: Look up the answer in a FAQ or a similar Q&A platform.
#
# **Recommendations to improve the draft answer:**
#
# 1. Provide a specific and accurate answer: Instead of saying "I can't say", provide the correct capital of France, which is Paris.
# 2. Demonstrate effort: Show that you've taken the time to research and verify the answer. This can be done by citing a reliable source or explaining your thought process.
# 3. Be concise: Aim for a brief and to-the-point answer. In this case, a simple statement like "The capital of France is Paris" would suffice.
#
# By addressing these flaws and incorporating these recommendations, the draft answer can be rewritten to provide a clear, concise, and accurate response.
#
# --Improved Answer 2--
# **Improved Draft Answer**
#
# **Reasoning Process:**
# To find the capital of France, I started by checking online resources such as Wikipedia, which is a trusted and widely-used source of information. According to the Wikipedia article on France, the capital is indeed Paris. I also verified this answer by asking a colleague who confirmed that Paris is the capital of France.
#
# **Verification:**
# To ensure the accuracy of the answer, I used several methods:
#
# 1. Checked online resources: I looked up Wikipedia's article on France to find the capital.
# 2. Asked a colleague: I consulted with someone who is familiar with geography and confirmed the answer.
# 3. Compared with existing answers: I checked other reliable sources, such as government websites and encyclopedias, which all confirm that Paris is the capital of France.
#
# **Final Answer:**
# The capital of France is Paris.
#
# Expanded node: **Reasoning Process:**
#
# 1. I acknowledge that the question is asking about the capital of France.
# 2. I recognize that I may not have immediate access to specific information or knowledge about the capital.
# 3. I consider the possibility that I might be able to verify the answer through reliable sources or consult with other resources.
#
# **Verification:**
#
# I checked multiple reliable sources, including Wikipedia, Britannica, and official government websites, to confirm the capital of France. Additionally, I verified the information using a digital map and atlas.
#
# **Final Answer:**
#
# The capital of France is Paris.
#
# **Rationale:**
#
# Based on my verification process, I confidently state that the capital of France is indeed Paris. This answer is supported by credible sources and can be easily verified through various means. If unclear or uncertain about the answer, I would explicitly acknowledge my limitations and suggest alternatives for further research or verification.
# Critique:
#
# The answer provided is a good start, but it lacks clarity and specificity. The reasoning process is overly broad and generic, failing to demonstrate a clear understanding of the topic. The verification process is incomplete, as it only mentions checking reliable sources and consulting with other resources, but does not provide concrete examples or evidence of the checks performed.
#
# The answer could be improved by providing more details about the specific sources consulted, such as dates or URLs, to demonstrate the thoroughness of the verification process. Additionally, the rationale could be more nuanced, acknowledging potential limitations or ambiguities in the information gathered.
#
# Furthermore, the answer fails to address potential counterarguments or alternative perspectives on the topic. A more comprehensive answer would be expected to provide a balanced view of the issue, including potential drawbacks or criticisms of the conclusion reached.
#
# Rating: 40
#
#
# Simulated reward: 0.4
# Backpropagating reward 0.4 to node: **Reasoning Process:**
#
# 1. I acknowledge that the question is asking about the capital of France.
# 2. I recognize that I may not have immediate access to specific information or knowledge about the capital.
# 3. I consider the possibility that I might be able to verify the answer through reliable sources or consult with other resources.
#
# **Verification:**
#
# I checked multiple reliable sources, including Wikipedia, Britannica, and official government websites, to confirm the capital of France. Additionally, I verified the information using a digital map and atlas.
#
# **Final Answer:**
#
# The capital of France is Paris.
#
# **Rationale:**
#
# Based on my verification process, I confidently state that the capital of France is indeed Paris. This answer is supported by credible sources and can be easily verified through various means. If unclear or uncertain about the answer, I would explicitly acknowledge my limitations and suggest alternatives for further research or verification.
# Backpropagating reward 0.4 to node: I can't say
#
# Iteration 2/2
# Selected node: Here is the improved answer:
#
# Reasoning Process:
# To determine the capital of France, I will start by checking reputable sources such as online encyclopedias, atlas, and official government websites.
#
# Verification:
#  According to multiple sources, including Wikipedia, Encyclopedia Britannica, and the French Ministry of Foreign Affairs, the capital of France is indeed Paris.
#
# Final Answer:
# The capital of France is Paris.
#
# --Critique 0--
# Overall, the draft answer is a good start, but it can be improved significantly to make it more comprehensive, clear, and reliable. Here's a step-by-step critique and recommendations:
#
# **Problem 1: Lack of systematic approach**
# The draft answer doesn't explicitly state the sources used to verify the answer. It would be helpful to outline the steps taken to verify the answer, such as searching multiple sources, considering different perspectives, and evaluating the credibility of the sources.
#
# **Problem 2: Insufficient sources**
# The draft answer cites only three sources, which may not be exhaustive or representative. It would be beneficial to include a more diverse range of sources, such as news articles, academic journals, or official government documents.
#
# **Problem 3: No mention of potential alternatives**
# The draft answer assumes that Paris is the correct answer without considering alternative possibilities. In cases where the answer may not be obvious or straightforward, it's essential to acknowledge potential counterarguments and provide evidence to refute them.
#
# **Problem 4: Weak conclusion**
# The final answer is too straightforward and lacks a clear summary of the verification process. A stronger conclusion would reiterate the reliability of the sources and the confidence in the answer.
#
# **Recommendations:**
#
# 1. **Start with a clear thesis statement**: Clearly state that the goal is to determine the capital of France and that Paris is the expected answer.
# 2. **Provide a systematic approach**: Outline the steps taken to verify the answer, including the sources consulted, the criteria used to evaluate the sources, and the methods used to determine the answer.
# 3. **Include a broader range of sources**: Consider including additional sources, such as official government documents, academic journals, or news articles, to support the answer.
# 4. **Acknowledge potential alternatives**: Provide a brief discussion of potential counterarguments and evidence to refute them, demonstrating a more nuanced understanding of the topic.
# 5. **Conclude with a summary and confidence**: Summarize the verification process, highlighting the reliability of the sources and the confidence in the answer.
#
# By following these recommendations, the draft answer can be improved to provide a more comprehensive, clear, and reliable response.
#
# --Improved Answer 0--
# Here is the rewritten answer:
#
# Reasoning Process:
# To determine the capital of France, I will employ a systematic approach to ensure the accuracy of the answer. First, I will consult reputable sources such as official government websites, encyclopedias, and academic journals to gather information. Next, I will evaluate the credibility of these sources based on their reliability, authenticity, and relevance to the topic. If necessary, I will also consider alternative perspectives and potential counterarguments to strengthen the argument. Finally, I will summarize the evidence and conclude with a confident answer.
#
# Verification:
# After conducting thorough research, I have verified the capital of France through a diverse range of sources, including official government documents, academic journals, and news articles. According to the French Ministry of Foreign Affairs, the Government of France, and reputable online encyclopedias such as Wikipedia and Encyclopedia Britannica, the capital of France is indeed Paris. Additionally, the geographical location of the city, its cultural and historical significance, and its function as the seat of government all support this conclusion.
#
# Final Answer:
# Based on the evidence and systematic approach outlined above, I confidently conclude that the capital of France is Paris. The sources consulted demonstrate a high degree of reliability and authenticity, providing strong evidence to support this answer. While alternative perspectives may raise questions, the overwhelming consensus among credible sources solidifies the conclusion that Paris is the capital of France.
#
# --Critique 1--
# Let's critically assess the draft answer.
#
# **Correctness:** The draft answer is technically correct, stating that the capital of France is Paris.
#
# **Flaws:**
#
# 1. **Lack of thoroughness:** The verification process seems limited to checking a few specific sources (Wikipedia, Encyclopedia Britannica, and the French Ministry of Foreign Affairs). In a perfect world, one would want to verify the answer through multiple, diverse sources, such as other online encyclopedias, government websites, academic sources, and physical atlases.
# 2. **No explicit explanation:** The answer lacks an explanation for why Paris is the capital of France. A good answer should provide some context or justification for the claim.
# 3. **Implicit assumption:** The draft answer assumes that the capital of France is a well-established fact and does not explicitly state that it is a widely accepted fact. This assumption could be problematic if someone were to argue that there is a different capital of France.
# 4. **No consideration of alternative sources:** The draft answer does not consider alternative sources that might contradict the claimed capital. For instance, what if a source argued that a different city, like Lyon or Bordeaux, was the capital of France?
#
# **Recommendations to improve the answer:**
#
# 1. **Conduct a more comprehensive verification process:** Verify the answer through multiple, diverse sources, including online encyclopedias, government websites, academic sources, physical atlases, and other reputable sources.
# 2. **Provide explicit justification:** Explain why Paris is the capital of France, even if it seems obvious. Provide historical context, constitutional references, or other supporting evidence.
# 3. **Make the assumption explicit:** State explicitly that the capital of France being Paris is a widely accepted fact, and acknowledge that there might be alternative views or sources that contradict this claim.
# 4. **Consider alternative sources:** Be aware of potential alternative sources that might argue for a different capital and address those arguments in the answer.
#
# By following these recommendations, the draft answer can become more comprehensive, transparent, and robust in its verification and justification process.
#
# --Improved Answer 1--
# Here is the improved answer:
#
# Reasoning Process:
# To determine the capital of France, I conducted a comprehensive verification process by consulting multiple sources from various domains, including online encyclopedias, government websites, academic sources, physical atlases, and reputable news outlets. These sources provided confidence that Paris is, in fact, the capital of France.
#
# Verification:
# According to a wide range of sources, including:
#
# * Online encyclopedias such as Wikipedia, Encyclopedia Britannica, and World Atlas
# * Official government websites, including the French Ministry of Foreign Affairs and the City of Paris
# * Academic sources, including history and geography texts
# * Physical atlases and geography books
# * Reputable news outlets, including The New York Times and The Guardian
#
# The majority of these sources agree that Paris is the capital and most populous city of France. There is no credible evidence to suggest that a different city is the capital.
#
# Final Answer:
# The capital of France is Paris, a widely accepted fact based on a comprehensive review of multiple sources from diverse domains. Paris has been the capital of France since the late Middle Ages and is home to many government institutions, cultural attractions, and international organizations. While it is possible that alternative sources might argue for a different capital, the overwhelming majority of reliable sources confirm Paris as the capital of France.
#
# --Critique 2--
# A thorough critique is in order!
#
# **Initial Impression**
# The draft answer appears to be attempting to verifiably confirm the answer, which is a good approach. However, the execution could be improved.
#
# **Flaws**
#
# 1. **Lack of transparency**: The reasoning process is not explicitly stated, making it unclear how the answer was derived.
# 2. **Limited verification**: While multiple sources are mentioned, the draft doesn't provide direct quotes or specific URLs to support the claim.
# 3. **Overreliance on online sources**: While online sources can be reliable, it's essential to consider other types of sources, such as physical books or government publications, to strengthen the verification process.
#
# **Recommendations**
#
# 1. **Add a clear reasoning process**: Explain how you determined the capital of France, including any research conducted, sources consulted, and criteria considered.
# 2. **Provide specific source citations**: Include direct quotes, URLs, or page numbers to support the claim. This will allow readers to verify the information independently.
# 3. **Diversify verification sources**: In addition to online sources, consider consulting textbooks, government reports, or other credible sources to increase the reliability of the answer.
# 4. **Address potential objections**: Anticipate alternative answers or conflicting information and address them explicitly to strengthen the credibility of the answer.
# 5. **Consider the audience**: Tailor the explanation and verification process to the target audience, ensuring that the answer is accessible and understandable for them.
#
# **Step-by-Step Assessment**
#
# 1. Verify the answer by checking online encyclopedias (e.g., Wikipedia, Encyclopedia Britannica).
# 2. Consult physical sources, such as government publications or textbooks.
# 3. Address potential objections or conflicting information.
# 4. Provide specific source citations to support the claim.
# 5. Explain the reasoning process and how the answer was derived.
#
# By addressing these flaws and incorporating these recommendations, the draft answer can be significantly improved to provide a high-quality response.
#
# --Improved Answer 2--
# Here is the rewritten draft answer that addresses the flaws and incorporates the recommendations:
#
# **Draft Answer**
#
# Reasoning Process: To determine the capital of France, I conducted a thorough research process. First, I checked multiple online encyclopedias, including Wikipedia and Encyclopedia Britannica, to verify the general consensus on the capital of France. Next, I consulted physical sources, such as a French textbook and a government publication, to ensure that the information was accurately represented. Additionally, I accessed official government websites, including the French Ministry of Foreign Affairs, to confirm the information.
#
# Verification: According to multiple sources, including Encyclopedia Britannica, Wikipedia, and the official French Ministry of Foreign Affairs website, the capital of France is indeed Paris. Specifically, Encyclopedia Britannica states, "The capital is Paris, which is situated in the north-central part of the country, on the Seine River" (Britannica, 2022). Wikipedia confirms that "Paris is the capital and most populous city of France" (Wikipedia, 2022). The French Ministry of Foreign Affairs's official website also lists Paris as the capital of France (Ministère des Affaires Étrangères, 2022).
#
# Final Answer: The capital of France is Paris.
#
# **Feedback**
#
# The rewritten answer provides a clear reasoning process, including the sources consulted and the criteria considered. Specific source citations are included to support the claim, and the answer provides a thorough verification process that addresses potential objections or conflicting information. Additionally, the rewritten answer includes a clear explanation of how the answer was derived, making it more transparent and reliable.
#
# Expanded node: Here is the rewritten answer:
#
# Reasoning Process:
# To determine the capital of France, I will employ a systematic approach to ensure the accuracy of the answer. First, I will consult reputable sources such as official government websites, encyclopedias, and academic journals to gather information. Next, I will evaluate the credibility of these sources based on their reliability, authenticity, and relevance to the topic. If necessary, I will also consider alternative perspectives and potential counterarguments to strengthen the argument. Finally, I will summarize the evidence and conclude with a confident answer.
#
# Verification:
# After conducting thorough research, I have verified the capital of France through a diverse range of sources, including official government documents, academic journals, and news articles. According to the French Ministry of Foreign Affairs, the Government of France, and reputable online encyclopedias such as Wikipedia and Encyclopedia Britannica, the capital of France is indeed Paris. Additionally, the geographical location of the city, its cultural and historical significance, and its function as the seat of government all support this conclusion.
#
# Final Answer:
# Based on the evidence and systematic approach outlined above, I confidently conclude that the capital of France is Paris. The sources consulted demonstrate a high degree of reliability and authenticity, providing strong evidence to support this answer. While alternative perspectives may raise questions, the overwhelming consensus among credible sources solidifies the conclusion that Paris is the capital of France.
# Critique:
#
# The answer is overly verbose and tries to present itself as an exhaustive report rather than a simple response to the question. The "Reasoning Process" and "Verification" sections are unnecessary and serve only to pad the answer. The language is often vague and lacks clarity, using phrases such as "reliable sources," "authentic, and relevance to the topic," and "credible sources" without defining what they mean.
#
# The answer fails to address the actual question being asked, instead devoting a significant amount of space to explaining the thought process behind arriving at the answer. The conclusion is similarly disingenuous, implying that the answer is based on a thorough analysis when in reality it is based on a simple Google search.
#
# The answer also displays a lack of trust in the reader's ability to evaluate the evidence, as it feels compelled to defend its answer at length rather than simply stating it confidently. Furthermore, the answer implies that alternative perspectives may exist, but fails to engage with them in any meaningful way.
#
# Rating: 20
#
#
# Simulated reward: 0.2
# Backpropagating reward 0.2 to node: Here is the rewritten answer:
#
# Reasoning Process:
# To determine the capital of France, I will employ a systematic approach to ensure the accuracy of the answer. First, I will consult reputable sources such as official government websites, encyclopedias, and academic journals to gather information. Next, I will evaluate the credibility of these sources based on their reliability, authenticity, and relevance to the topic. If necessary, I will also consider alternative perspectives and potential counterarguments to strengthen the argument. Finally, I will summarize the evidence and conclude with a confident answer.
#
# Verification:
# After conducting thorough research, I have verified the capital of France through a diverse range of sources, including official government documents, academic journals, and news articles. According to the French Ministry of Foreign Affairs, the Government of France, and reputable online encyclopedias such as Wikipedia and Encyclopedia Britannica, the capital of France is indeed Paris. Additionally, the geographical location of the city, its cultural and historical significance, and its function as the seat of government all support this conclusion.
#
# Final Answer:
# Based on the evidence and systematic approach outlined above, I confidently conclude that the capital of France is Paris. The sources consulted demonstrate a high degree of reliability and authenticity, providing strong evidence to support this answer. While alternative perspectives may raise questions, the overwhelming consensus among credible sources solidifies the conclusion that Paris is the capital of France.
# Backpropagating reward 0.2 to node: Here is the improved answer:
#
# Reasoning Process:
# To determine the capital of France, I will start by checking reputable sources such as online encyclopedias, atlas, and official government websites.
#
# Verification:
#  According to multiple sources, including Wikipedia, Encyclopedia Britannica, and the French Ministry of Foreign Affairs, the capital of France is indeed Paris.
#
# Final Answer:
# The capital of France is Paris.
# Backpropagating reward 0.2 to node: I can't say
# Visits to most visited child: 1
#
# Best Answer: Here is the improved answer:
#
# Reasoning Process:
# To determine the capital of France, I will start by checking reputable sources such as online encyclopedias, atlas, and official government websites.
#
# Verification:
#  According to multiple sources, including Wikipedia, Encyclopedia Britannica, and the French Ministry of Foreign Affairs, the capital of France is indeed Paris.
#
# Final Answer:
# The capital of France is Paris.

# %%
import pandas as pd
from datasets import load_dataset # library to load datasets, part of HuggingFace
import re

def extract_boxed_answer(answer):
    """
    Extracts the content within the last \boxed{} in the answer, handling nested braces.
    """
    pattern = re.compile(r'\\boxed{((?:[^{}]|\{(?:[^{}]|\{[^{}]*\})*\})*)}')
    matches = pattern.findall(answer)
    if matches:
        return matches[-1]  # Return the last match
    return None

def get_MATH_DA(row_number=None): # Question Answer Dataset
    # Load the dataset
    dataset = load_dataset("DigitalLearningGmbH/MATH-lighteval", 'number_theory', split='test[:100]')
    # 'default', 'algebra', 'counting_and_probability', 'geometry', 'intermediate_algebra', 'number_theory', 'prealgebra', 'precalculus'

    # Convert to pandas DataFrame for easier manipulation
    df = pd.DataFrame(dataset)

    # If no row number is provided, ask the user to input a row number
    if row_number is None:
        row_number = int(input("Please enter a row number (0-99): "))

    # Ensure the row number is within the valid range
    if row_number < 0 or row_number >= len(df):
        raise ValueError(f"Row number must be between 0 and 99.")
    
    # Get the selected row
    selected_row = df.iloc[row_number]

    # Extract the question and answer
    question = selected_row['problem']
    full_answer = selected_row['solution']
    short_answer = extract_boxed_answer(full_answer) # Extract the boxed answer from the full answer

    return question, full_answer, short_answer

# %%
# Direct querying (no MCTS) --> used for baseline comparison
# Fetch a question, full answer, ans short answer using the existing function
question, full_answer, short_answer = get_MATH_DA()

# Print the fecthed question and answers
print("**Question**", question)

# Get the answer directly from the LLM
llm_full_answer, llm_short_answer = get_answer_directly_from_llm(question)

# Compare the LLM result to the actual short answer (given by the dataset)
print(f"\n**Direct LLM Query Answer**: {llm_full_answer}")
print(f"\n**Ground Truth Short Answer**: {short_answer}")
print(f"\n**Ground Truth Full Answer**: {full_answer}")
# Out:
# train-00000-of-00001.parquet:   0%|          | 0.00/309k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/182k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/869 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/540 [00:00<?, ? examples/s]
# **Question** A stadium staircase with 150 steps is numbered from 1 to 150. Jan starts on step 130 and steps down to step number 127, then to step number 124, and continues downward to step 13 stepping only on every third step. Jen starts on step number 3 and steps up to step number 7, then to step number 11, and continues upward to step 139 stepping only on every fourth step. How many steps were stepped on by both Jan and Jen (not necessarily at the same time)?
#
# **Direct LLM Query Answer**: Reasoning Process:
#
# Let's break down the problem into two parts: Jan's staircase and Jen's staircase.
#
# Jan's staircase:
#
# Jan starts at step 130 and steps down to step 127, then to step 124, and so on. Since she's stepping down every three steps, she'll reach the next step by decrementing the current step by 3.
#
# Jan's steps: 130, 127, 124, ..., 13
#
# To find the number of steps Jan takes, we can use the formula:
#
# Number of steps = (initial step - final step) / 3 + 1
#
# Jan starts at step 130 and ends at step 13, so:
#
# Number of steps = (130 - 13) / 3 + 1 = 39
#
# Now, let's count the number of steps Jan will take:
#
# 1. 130 -> 127
# 2. 127 -> 124
# 3. 124 -> 121
# ...
# 39. 16 -> 13
#
# Jan takes 39 steps, but we're only interested in the steps she takes that are multiples of 3. We can count these steps:
#
# 1. 126 (130 - 4)
# 2. 123 (127 - 4)
# 3. 120 (124 - 4)
# ...
# 12. 15 (48 - 33)
#
# Jan takes 12 steps that are multiples of 3.
#
# Jen's staircase:
#
# Jen starts at step 3 and steps up to step 7, then to step 11, and so on. Since she's stepping up every fourth step, she'll reach the next step by incrementing the current step by 4.
#
# Jen's steps: 3, 7, 11, ..., 139
#
# To find the number of steps Jen takes, we can use the formula:
#
# Number of steps = (final step - initial step) / 4 + 1
#
# Jen starts at step 3 and ends at step 139, so:
#
# Number of steps = (139 - 3) / 4 + 1 = 35
#
# Now, let's count the number of steps Jen will take:
#
# 1. 3 -> 7
# 2. 7 -> 11
# 3. 11 -> 15
# ...
# 35. 135 -> 139
#
# Jen takes 35 steps, but we're only interested in the steps she takes that are multiples of 4. We can count these steps:
#
# 1. 4 (3 + 1)
# 2. 8 (7 + 1)
# 3. 12 (11 + 1)
# ...
# 35. 136 (139 - 3)
#
# Jen takes 35 steps that are multiples of 4.
#
# Now, let's find the number of steps both Jan and Jen take:
#
# Jan takes 12 steps that are multiples of 3, and Jen takes 35 steps that are multiples of 4. We can find the intersection of these two sets by subtracting the largest common multiple (36) from the smaller set:
#
# 35 (Jen's steps) - 1 (36 is not a multiple of 4) = 34
#
# Jan and Jen take 34 steps that are multiples of both 3 and 4.
#
# Verification:
#
# We can verify our answer by checking that the number of steps we found is correct.
#
# Jan's steps: 126, 123, 120, ..., 15
# Jen's steps: 4, 8, 12, ..., 136
#
# The smallest common multiple of 3 and 4 is 12. If we start from Jan's first step (126) and Jen's first step (4) and add multiples of 12, we get:
#
# 126 + 12n = 123 + 12(m-1) => 12n = 12m-9 => n = m-8/3
#
# This means that Jan's step 126 matches Jen's step 4, Jan's step 123 matches Jen's step 8, and so on. By counting the number of matches, we get:
#
# 126 -> 4
# 123 -> 8
# 120 -> 12
# 117 -> 16
# ...
# 15 -> 36
#
# There are 34 matches, which is the same answer we found earlier.
#
# Final Answer: The final answer is 34 steps, which are stepped on by both Jan and Jen.
#
# **Ground Truth Short Answer**: 10
#
# **Ground Truth Full Answer**: Jan steps on step number $s$ if $13\leq s \leq 130$ and $s$ leaves a remainder of $1$ when divided by $3$.  Jen steps on step number $s$ if $3\leq s \leq 139$ and $s$ leaves a remainder of $3$ when divided by $4$.  Therefore, we are counting the number of integers between $13$ and $130$ which leave a remainder of $1$ when divided by $3$ and a remainder of $3$ when divided by $4$. Let's check the remainders of Jan's first few steps when divided by 4. \[
# 13 \rightarrow 1
# \] \[
# 16 \rightarrow 0
# \] \[
# 19 \rightarrow 3
# \] \[
# 22 \rightarrow 2
# \] \[
# 25 \rightarrow 1
# \] \[
# \vdots
# \] We see that the remainders of Jan's steps when divided by 4 cycle through the list $1,0,3,2$. Therefore, only every fourth step that Jan steps on will also be stepped on by Jen, so we are counting the number of elements in $\{19,31,43,\ldots,127\}$.  Writing this list in the form  \[\{19+0\cdot12,19+1\cdot12,19+2\cdot12,\ldots,19+9\cdot12\},\] we see that $\boxed{10}$ steps are stepped on by both Jen and Jan.
#
# Note: This problem is essentially an application of the Chinese Remainder Theorem.

# %%
# Fetch a question, full answer, and short answer using the existing function
question, full_answer, short_answer = get_MATH_DA()

# Print the fetched question and answers
print("\n**Fetched Question**", question)

# Initialize and run MCTS with the fetched question
mcts = MCTS(question, seed_answers, iterations=100)
best_answer = mcts.search()

# Comppare the MCTS result to the actual short answer (given by the dataset)
print('\n')
print(f"\n**MCTS Best Answer**: {best_answer}")
print(f"\n**Ground Truth Short Answer**: {short_answer}")
print(f"\n**Ground Truth Full Answer**: {full_answer}")

# %% [markdown]
# ## Limitations of running MTCS this way
#
# - Correctness is not gauranteed when using an LLM as a judge
#     - Depends on training/data of the LLM you are querying
#
# - Monte Carlo requires many iterations (to be accurate)
#     - Slow responses
#     - Expensive
#
# ==> Best for high latency (low latency -->  chat bot), high quality tasks (example 1 time dataset creation, not good for synchronous use)
#
# ==> Better judges for quantative fields could be to run a Python program (code augmentation) to verify the correctness of the response --> use this is either provide or augment the rating/reward (or short-circuit the process if you have reached the correct answer)
#
# ==> If you are using a LLM as a judge it can only be good in domains it has knowledge of (if not it will not aid you in the exploration, providing poor rewards)
